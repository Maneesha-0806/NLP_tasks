# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt

articles = [
    "Artificial intelligence is transforming healthcare and education systems",
    "AI and machine learning are the future of technology and innovation",
    "Healthcare systems are improving with artificial intelligence solutions",
    "Education technology is growing rapidly with AI based tools"
]

text = " ".join(articles).lower()

text = text.translate(str.maketrans('', '', string.punctuation))

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

print("Filtered Tokens:")
print(filtered_tokens)

freq_dist = Counter(filtered_tokens)

print("\nWord Frequency Distribution:")
for word, count in freq_dist.items():
    print(f"{word}: {count}")

vocabulary = set(filtered_tokens)

print("\nVocabulary:")
print(vocabulary)

print("\nVocabulary Size:", len(vocabulary))

top5 = freq_dist.most_common(5)

print("\nTop 5 Most Frequent Words:")
for word, count in top5:
    print(f"{word}: {count}")

total_tokens = len(filtered_tokens)
unique_tokens = len(vocabulary)

ttr = unique_tokens / total_tokens

print("\nType-Token Ratio (TTR):", round(ttr, 3))

topic_keywords = {
    "Artificial Intelligence": ["artificial", "intelligence", "ai"],
    "Healthcare": ["healthcare"],
    "Education": ["education"],
    "Technology": ["technology", "machine", "learning", "innovation", "tools"]
}

topic_scores = {}

for topic, keywords in topic_keywords.items():
    score = sum(freq_dist[word] for word in keywords if word in freq_dist)
    topic_scores[topic] = score

dominant_topic = max(topic_scores, key=topic_scores.get)

print("\nTopic Scores:")
for topic, score in topic_scores.items():
    print(f"{topic}: {score}")

print("\nDominant Topic:", dominant_topic)

words = [word for word, count in top5]
counts = [count for word, count in top5]

plt.figure(figsize=(8, 5))
plt.bar(words, counts)
plt.title("Top 5 Most Frequent Words")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()
# Out:
# Filtered Tokens:
# ['artificial', 'intelligence', 'transforming', 'healthcare', 'education', 'systems', 'ai', 'machine', 'learning', 'future', 'technology', 'innovation', 'healthcare', 'systems', 'improving', 'artificial', 'intelligence', 'solutions', 'education', 'technology', 'growing', 'rapidly', 'ai', 'based', 'tools']
#
# Word Frequency Distribution:
# artificial: 2
# intelligence: 2
# transforming: 1
# healthcare: 2
# education: 2
# systems: 2
# ai: 2
# machine: 1
# learning: 1
# future: 1
# technology: 2
# innovation: 1
# improving: 1
# solutions: 1
# growing: 1
# rapidly: 1
# based: 1
# tools: 1
#
# Vocabulary:
# {'intelligence', 'learning', 'ai', 'systems', 'technology', 'growing', 'rapidly', 'tools', 'future', 'solutions', 'education', 'healthcare', 'improving', 'transforming', 'based', 'artificial', 'machine', 'innovation'}
#
# Vocabulary Size: 18
#
# Top 5 Most Frequent Words:
# artificial: 2
# intelligence: 2
# healthcare: 2
# education: 2
# systems: 2
#
# Type-Token Ratio (TTR): 0.72
#
# Topic Scores:
# Artificial Intelligence: 6
# Healthcare: 2
# Education: 2
# Technology: 6
#
# Dominant Topic: Artificial Intelligence
